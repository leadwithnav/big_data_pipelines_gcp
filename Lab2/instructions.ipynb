# %% [markdown]
# ### Lab 2: Google Cloud Pub/Sub Publisher and Subscriber

# %% [markdown]
# ### Meet Robo2: Your Lab Buddy!
# <table>
#     <tr>
#         <td style="width:50%; text-align:center;">
#             <img src="../images/robo1.png" alt="Robo1" style="max-width:100%;">
#         </td>
#         <td style="width:50%; ">
#             <ul>
#                 <li>Publishing and subscribing to events is my jam—I’ll get your messages flowing like a well-oiled Pub/Sub pipeline.</li>
#             </ul>
#         </td>
#     </tr>
# </table>
# ---

# %% [markdown]
# In this lab, you will learn how to use the Google Cloud Pub/Sub Python client libraries to create a publisher and subscriber.
# We will use IoT telemetry data source (`sensor_data.csv` containing 1000 randomized device logs). The publisher reads this file, injects the current UTC timestamp, and publishes it continuously to a Pub/Sub topic. The subscriber listens to a subscription on that topic, receives and prints the messages in real-time, and acknowledges them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;"> Open Cloud Shell and Set Environment Variables</span>
#
# Run the following commands in your Cloud Shell to set up environment variables for your project and region:

# %%
export PROJECT_ID=<your project id>
echo "Project ID : $PROJECT_ID"

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Enable the Cloud Pub/Sub API</span>
#
# Before running the publisher or subscriber scripts, you must ensure that the Cloud Pub/Sub API is enabled in your Google Cloud project.</br>
#
# Run the following command in your Cloud Shell to enable the API:

# %%
gcloud services enable pubsub.googleapis.com --project=${PROJECT_ID}

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 3:</span> <span style="color:#1976d2;">Create Pub/Sub Topic and Subscription</span>
#
# Run the following commands in your Cloud Shell terminal to create the topic and its subscription:
# </br></br>

# %%
# Create the Pub/Sub Topic
gcloud pubsub topics create lab2-topic --project=${PROJECT_ID}

# Create a pull subscription bound to the topic
gcloud pubsub subscriptions create lab2-sub --topic=lab2-topic --project=${PROJECT_ID}

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Install Requirements</span>
#
# Navigate to the `Lab2` directory and install the necessary dependencies:

# %%
# Navigate to the Lab 2 directory
cd ~/big_data_pipelines_gcp/Lab2

# Install the google-cloud-pubsub package
pip install -r requirements.txt

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 5:</span> <span style="color:#1976d2;">Run the Telemetry Publisher</span>
#
# Start the publisher. It reads the local `sensor_data.csv` (containing randomized device records) and publishes each record directly to `lab2-topic`.

# %%
python publisher.py --project=${PROJECT_ID}

# %% [markdown]
# <span style="color:#a52a2a; font-weight:bold;">Keep this script running. Open a new Cloud Shell tab/terminal to execute the subscriber.</span>

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Use Copilot Explain</span>
#
# Use Github Copilot Review  to review your code. Copilot might tell you what are the potential issues and suggest you changes</br>
#
# <span style="color:green;">Select the code  → right click  → Generate code -> Review</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Accept/Discard the changes</span>
#
# Review the comments provided. You can either accept or discard the changes and move to next comment</br></br>
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 3: Adding New Test with Copilot

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open ecommerce.spec.js from Lab2</span>

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Use Inline Editor</span>
#
# - Place your cursor after TC-001.
# - Open the inline editor using Ctrl+I.
# - In the prompt, type # and choose the file from the picker (or type the filename directly, like #ecommerceJira.md).
# - Write your instruction and press Enter.
# - Select the model you want to use for code generation (e.g., GPT-4).
#
# Prompt
# - <code>Using summary and assumptions provided in Jira story Ec-201 from #ecommerceJira.md as reference, add a new test case TC-002: Add item to cart and verify cart count</code>
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <table>
#     <tr>
#         <td style="width:50%; text-align:center;">
#             <img src="../images/robo2.png" alt="Robo1" style="max-width:100%;">
#         </td>
#         <td style="width:50%; vertical-align:middle;">
#             <span style="font-size:120%; color:#1976d2; font-weight:bold;">
#                 🎉 Congratulations!</span><br>You did it!<br>
#                 <span style="color:#43a047;">Happy Coding with your new skills!</span><br>
#             </span>
#         </td>
#     </tr>
# </table>
